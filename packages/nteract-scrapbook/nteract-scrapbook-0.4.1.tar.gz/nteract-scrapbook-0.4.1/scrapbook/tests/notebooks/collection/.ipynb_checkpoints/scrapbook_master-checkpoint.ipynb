# %%
import scrapbook as sb
import IPython

# %%
sb.glue("one", 1)
sb.glue("number", 1)
sb.glue("list", [1,2,3])
sb.glue("dict", dict(a=1, b=2))
sb.glue("sharable_png",
  IPython.display.Image(filename="/home/mseal/Workspace/scrapbook/docs/_static/images/scrapbook-logo.png"),
  encoder='display'
)

sb.glue("output", "Hello World!", display=True)
sb.glue("one_only", "Just here!", display=True)
# Out:
# 'Hello World!'
# 'Just here!'
